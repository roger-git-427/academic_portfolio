# %%
from kedro_mlflow.io.metrics import MlflowMetricDataset

# %%
pip show kedro-mlflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\avril\Octavo_semestre\Reto-TCA-Series-de-tiempo\my-kedro-project\tca-pipeline\.venv\Scripts\python.exe: No module named pip

# %%
from kedro_mlflow.framework.hooks import MlflowHook
mlflow_hook = MlflowHook()
HOOKS = (mlflow_hook,)
# Out:
# [05/28/25 21:04:24] INFO     Using 'conf\logging.yml' as logging configuration. You can change this ]8;id=748840;file://c:\Users\avril\Octavo_semestre\Reto-TCA-Series-de-tiempo\my-kedro-project\tca-pipeline\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=725699;file://c:\Users\avril\Octavo_semestre\Reto-TCA-Series-de-tiempo\my-kedro-project\tca-pipeline\.venv\Lib\site-packages\kedro\framework\project\__init__.py#272\272]8;;\
#                              by setting the KEDRO_LOGGING_CONFIG environment variable accordingly.
# c:\Users\avril\Octavo_semestre\Reto-TCA-Series-de-tiempo\my-kedro-project\tca-pipeline\.venv\Lib\site-packages\mlflow\pyfunc\utils\data_validation.py:186: UserWarning: Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
#   color_warning(

# %%
filepath = "data/01_raw/reservaciones_tcabdfront2.csv"

# %%
import pandas as pd

df = pd.read_csv(filepath)

df.tail(10000)
# Out:
# C:\Users\avril\AppData\Local\Temp\ipykernel_11336\1556847419.py:3: DtypeWarning: Columns (22,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
#         ID_Reserva                Fecha_hoy  h_res_fec h_res_fec_ok  \
# 193002      193002  2020-02-18 00:00:00.000   20190218  2019-02-18
# 193003      193003  2020-02-18 00:00:00.000   20190218  2019-02-18
# 193004      193004  2020-02-18 00:00:00.000   20190218  2019-02-18
# 193005      193005  2020-02-18 00:00:00.000   20190218  2019-02-18
# 193006      193006  2020-03-14 00:00:00.000   20190314  2019-03-14
# ...            ...                      ...        ...          ...
# 202997      202997  2020-04-10 00:00:00.000   20190410  2019-04-10
# 202998      202998  2020-06-17 00:00:00.000   20190617  2019-06-17
# 202999      202999  2020-05-30 00:00:00.000   20190530  2019-05-30
# 203000      203000  2020-08-10 00:00:00.000   20190810  2019-08-10
# 203001      203001  2020-02-24 00:00:00.000   20190224  2019-02-24
#
#                   h_res_fec_okt  h_num_per  aa_h_num_per  h_num_adu  \
# 193002  2019-02-18 00:00:00.000          0             2          0
# 193003  2019-02-18 00:00:00.000          0             2          0
# 193004  2019-02-18 00:00:00.000          0             3          0
# 193005  2019-02-18 00:00:00.000          0             3          0
# 193006  2019-03-14 00:00:00.000          0             1          0
# ...                         ...        ...           ...        ...
# 202997  2019-04-10 00:00:00.000          0             2          0
# 202998  2019-06-17 00:00:00.000          0             2          0
# 202999  2019-05-30 00:00:00.000          0             3          0
# 203000  2019-08-10 00:00:00.000          0             2          0
# 203001  2019-02-24 00:00:00.000          0             2          0
#
#         aa_h_num_adu  h_num_men  ...   h_edo             h_codigop  \
# 193002             2          0  ...  EGR     40880
# 193003             2          0  ...  EGR     40880
# 193004             3          0  ...  EGR     40880
# 193005             2          0  ...  EGR     40880
# 193006             1          0  ...  EMX     06700
# ...              ...        ...  ...     ...                   ...
# 202997             2          0  ...  EMC     58197
# 202998             2          0  ...  EGR     5165165
# 202999             2          0  ...  EMC     60110
# 203000             2          0  ...  EMC     60432
# 203001             2          0  ...  EMC     61606
#
#         h_correo_e  h_nom  h_tfa_total  aa_h_tfa_total  moneda_cve  \
# 193002         NaN    NaN          0.0         6560.00           1
# 193003         NaN    NaN          0.0         6560.00           1
# 193004         NaN    NaN          0.0         9540.00           1
# 193005         NaN    NaN          0.0         7458.00           1
# 193006         NaN    NaN          0.0        10755.00           1
# ...            ...    ...          ...             ...         ...
# 202997         NaN    NaN          0.0         2659.95           1
# 202998         NaN    NaN          0.0          171.00           1
# 202999         NaN    NaN          0.0         2659.98           1
# 203000         NaN    NaN          0.0         7900.96           1
# 203001         NaN    NaN          0.0         2212.00           1
#
#         h_ult_cam_fec  h_ult_cam_fec_ok        h_ult_cam_fec_okt
# 193002       20191109       2019-11-09   2019-11-09 00:00:00.000
# 193003       20191109       2019-11-09   2019-11-09 00:00:00.000
# 193004       20191109       2019-11-09   2019-11-09 00:00:00.000
# 193005       20191109       2019-11-09   2019-11-09 00:00:00.000
# 193006       20190324       2019-03-24   2019-03-24 00:00:00.000
# ...               ...               ...                      ...
# 202997       20190410       2019-04-10   2019-04-10 00:00:00.000
# 202998       20190617       2019-06-17   2019-06-17 00:00:00.000
# 202999       20190602       2019-06-02   2019-06-02 00:00:00.000
# 203000       20190812       2019-08-12   2019-08-12 00:00:00.000
# 203001       20190228       2019-02-28   2019-02-28 00:00:00.000
#
# [10000 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['ID_Reserva', 'Fecha_hoy', 'h_res_fec', 'h_res_fec_ok', 'h_res_fec_okt',
#        'h_num_per', 'aa_h_num_per', 'h_num_adu', 'aa_h_num_adu', 'h_num_men',
#        'aa_h_num_men', 'h_num_noc', 'aa_h_num_noc', 'h_tot_hab',
#        'aa_h_tot_hab', 'ID_Programa', 'ID_Paquete', 'ID_Segmento_Comp',
#        'ID_Agencia', 'ID_empresa', 'ID_Tipo_Habitacion', 'ID_canal',
#        'h_fec_lld', 'h_fec_lld_ok', 'h_fec_lld_okt', 'h_fec_reg',
#        'h_fec_reg_ok', 'h_fec_reg_okt', 'h_fec_sda', 'h_fec_sda_ok',
#        'h_fec_sda_okt', 'ID_Pais_Origen', 'Cliente_Disp', 'aa_Cliente_Disp',
#        'Reservacion', 'aa_Reservacion', 'ID_estatus_reservaciones',
#        'h_can_res', 'h_cod_reserva', 'h_edo', 'h_codigop', 'h_correo_e',
#        'h_nom', 'h_tfa_total', 'aa_h_tfa_total', 'moneda_cve', 'h_ult_cam_fec',
#        'h_ult_cam_fec_ok', 'h_ult_cam_fec_okt'],
#       dtype='object')

# %%
import pandas as pd

# Ruta donde Kedro buscará los datos de inferencia
inference_filepath = "data/01_raw/reservaciones_inference.csv"

df_filtrado = df[df["h_tot_hab"] > 0]
# Filtrar las últimas 100 filas
df_inference = df_filtrado.tail(100)

# Guardar el archivo CSV sin el índice
df_inference.to_csv(inference_filepath, index=False)

# %%
df_inference.shape
# Out:
# (100, 49)

# %%
import numpy as np
import pandas as pd

# Reemplaza inf, -inf por NaN (por si los hay)
df_inference = df_inference.replace([np.inf, -np.inf], np.nan)

# Luego, reemplaza todos los NaN por un valor numérico válido (por ejemplo, 0 o -1)
df_inference = df_inference.fillna(0)  # puedes usar -1 si prefieres

# También puedes hacer esto si quieres solo limpiar columnas específicas
# df_inference["col1"] = df_inference["col1"].fillna(0)
df_inference.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 102099 to 102198
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID_Reserva                100 non-null    int64
#  1   Fecha_hoy                 100 non-null    object
#  2   h_res_fec                 100 non-null    int64
#  3   h_res_fec_ok              100 non-null    object
#  4   h_res_fec_okt             100 non-null    object
#  5   h_num_per                 100 non-null    int64
#  6   aa_h_num_per              100 non-null    int64
#  7   h_num_adu                 100 non-null    int64
#  8   aa_h_num_adu              100 non-null    int64
#  9   h_num_men                 100 non-null    int64
#  10  aa_h_num_men              100 non-null    int64
#  11  h_num_noc                 100 non-null    int64
#  12  aa_h_num_noc              100 non-null    int64
#  13  h_tot_hab                 100 non-null    int64
#  14  aa_h_tot_hab              100 non-null    int64
#  15  ID_Programa               100 non-null    int64
#  16  ID_Paquete                100 non-null    int64
#  17  ID_Segmento_Comp          100 non-null    int64
#  18  ID_Agencia                100 non-null    int64
#  19  ID_empresa                100 non-null    int64
#  20  ID_Tipo_Habitacion        100 non-null    int64
#  21  ID_canal                  100 non-null    int64
#  22  h_fec_lld                 100 non-null    int64
#  23  h_fec_lld_ok              100 non-null    object
#  24  h_fec_lld_okt             100 non-null    object
#  25  h_fec_reg                 100 non-null    object
#  26  h_fec_reg_ok              100 non-null    object
#  27  h_fec_reg_okt             100 non-null    object
#  28  h_fec_sda                 100 non-null    int64
#  29  h_fec_sda_ok              100 non-null    object
#  30  h_fec_sda_okt             100 non-null    object
#  31  ID_Pais_Origen            100 non-null    int64
#  32  Cliente_Disp              100 non-null    int64
#  33  aa_Cliente_Disp           100 non-null    int64
#  34  Reservacion               100 non-null    int64
#  35  aa_Reservacion            100 non-null    int64
#  36  ID_estatus_reservaciones  100 non-null    int64
#  37  h_can_res                 100 non-null    object
#  38  h_cod_reserva             100 non-null    object
#  39  h_edo                     100 non-null    object
#  40  h_codigop                 100 non-null    object
#  41  h_correo_e                100 non-null    float64
#  42  h_nom                     100 non-null    float64
#  43  h_tfa_total               100 non-null    float64
#  44  aa_h_tfa_total            100 non-null    float64
#  45  moneda_cve                100 non-null    int64
#  46  h_ult_cam_fec             100 non-null    object
#  47  h_ult_cam_fec_ok          100 non-null    object
#  48  h_ult_cam_fec_okt         100 non-null    object
# dtypes: float64(4), int64(28), object(17)
# memory usage: 39.1+ KB
# C:\Users\avril\AppData\Local\Temp\ipykernel_11336\2245664142.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_inference = df_inference.replace([np.inf, -np.inf], np.nan)

# %%
import requests

# Convertir a lista de diccionarios
data_dict = df_inference.to_dict(orient="records")
payload = { "data": data_dict }

# Enviar POST
url = "http://localhost:8080/predict"
response = requests.post(url, json=payload)

# Mostrar resultados
if response.status_code == 200:
    print("✅ Predicciones:")
    print(response.json())
else:
    print("❌ Error:", response.status_code)
    print(response.text)
# Out:
# ✅ Predicciones:
# {'predictions': [{'ds': '2021-05-02', 'yhat': 315.9443588052453, 'yhat_lower': 175.4385645712364, 'yhat_upper': 467.2116485242354}, {'ds': '2021-05-03', 'yhat': 358.6163850182446, 'yhat_lower': 210.83135798136223, 'yhat_upper': 500.28009044367184}, {'ds': '2021-05-04', 'yhat': 352.41068140559025, 'yhat_lower': 220.64813915188967, 'yhat_upper': 495.0602003254493}, {'ds': '2021-05-05', 'yhat': 274.54061713629153, 'yhat_lower': 120.53408348174347, 'yhat_upper': 418.33249476008547}, {'ds': '2021-05-06', 'yhat': 313.13026403999294, 'yhat_lower': 170.42369443155107, 'yhat_upper': 450.3870886054209}, {'ds': '2021-05-07', 'yhat': 468.3381190896774, 'yhat_lower': 325.14702826871417, 'yhat_upper': 610.4899811336783}, {'ds': '2021-05-08', 'yhat': 470.20900682274726, 'yhat_lower': 324.86515231531797, 'yhat_upper': 618.2154529138153}, {'ds': '2021-05-09', 'yhat': 328.4238677674505, 'yhat_lower': 182.79262390541763, 'yhat_upper': 464.4783824262867}, {'ds': '2021-05-10', 'yhat': 369.9276177399973, 'yhat_lower': 222.17365315381406, 'yhat_upper': 512.7065060520387}, {'ds': '2021-05-11', 'yhat': 362.4439889141645, 'yhat_lower': 213.7281014900067, 'yhat_upper': 506.44692511371255}, {'ds': '2021-05-12', 'yhat': 283.1448297749719, 'yhat_lower': 132.95130674127688, 'yhat_upper': 414.9084345073855}, {'ds': '2021-05-13', 'yhat': 320.149794005873, 'yhat_lower': 181.32503017196612, 'yhat_upper': 457.0192744085073}, {'ds': '2021-05-14', 'yhat': 473.61676917036084, 'yhat_lower': 322.0871240154859, 'yhat_upper': 617.9990209988661